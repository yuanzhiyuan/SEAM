# %% [markdown]
# # pre

# %% [markdown]
# ## import & setting

# %%
import anndata as ad
import scanpy as sc
import numpy as np
import seaborn as sns
import palettable
import scipy
import pandas as pd
import scipy.io as sio
import pickle
import sys
sys.path.append('/home/yzy/bioSIMS/code/analysis')
from utils_220 import *

sc.set_figure_params(dpi=500, color_map='viridis',dpi_save=500,transparent=True)
heatmap_cmp = palettable.cmocean.diverging.Balance_20.mpl_colormap
cls_cmp = palettable.cartocolors.qualitative.Bold_10.mpl_colors
# cls_cmp = palettable.cartocolors.qualitative.Safe_7.mpl_colors
# Out:
# /home/yzy/anaconda3/envs/scaden/lib/python3.7/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex
# Using TensorFlow backend.
# /home/yzy/anaconda3/envs/scaden/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.cluster.bicluster module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.cluster. Anything that cannot be imported from sklearn.cluster is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ## functions

# %%
def show_mz(matter,test_sample,matter_list):
    sns.set_style('white')
    m_idx = np.where(matter_list==matter)
    show_img = np.reshape(test_sample[:,m_idx],(256,256))
    plt.imshow(show_img,cmap='Reds')
    plt.title(str(matter))
    plt.show()

# %%
def get_adj_matters(key_matters,matter_list):
    key_matters = np.array(key_matters).astype('float')
    matter_list = np.array(matter_list).astype('float')
    adjested_key_matters = []
    for k in key_matters:
        m_diff = np.abs(matter_list-k)
        min_diff_idx = np.argmin(m_diff)
        min_diff_m = matter_list[min_diff_idx]
        adjested_key_matters.append(min_diff_m)
    adjested_key_matters = np.array(adjested_key_matters)
    return adjested_key_matters

# %%
def add_subcls(a_cls_sub,ec_cls,to_replace_cls):
    a_cls_sub_int = a_cls_sub.astype('int')
    a_cls_sub_int[a_cls_sub_int==int(to_replace_cls)] = -1
    a_cls_sub_int[a_cls_sub_int>int(to_replace_cls)]-=1
    a_cls_sub_int_max = a_cls_sub_int.max()
    
    ec_cls_int = ec_cls.astype('int')
    ec_cls_int -= ec_cls_int.min()
    ec_cls_int+=(a_cls_sub_int_max+1)
    a_cls_sub_int[a_cls_sub_int==-1] = ec_cls_int
    return a_cls_sub_int.astype('str')

# %%
def ind2ij(ind,size,axis):
    i,j=divmod(ind-1,size)
    i+=1
    j+=1
    return np.array([i,j])[axis]

# %%
def get_train_data(data_mat_filename,mode,norm,batch_num_list=[1]):
#     mode分为:'none','median','total'
#     norm分为:'none',standard','l1','l2'
#     batch_num_list = [3,5]
    # 5行
    # 1,2,3,4,5,6
    # batch_num = 4


    original_data = {}
    cell_related_data = {}
    data_mat = sio.loadmat(data_mat_filename)
    data_mat=data_mat['data_mat']



    num_features = data_mat.shape[1]-3
    batch_dict = {}

    label_dict = {}
    cell_dict = {}
    pos_dict = {}

    for i in range(1):

            cur_data = data_mat[data_mat[:,0]==i+1,3:num_features+3]


            batch_dict[i+1] = cur_data

            cell_dict[i+1] = data_mat[data_mat[:,0]==i+1,1]
            cur_batch_idx = data_mat[data_mat[:,0]==i+1,2]
            label_dict[i+1] = np.ones(shape=cur_batch_idx.shape)


            pos_dict[i+1] = cur_batch_idx
    original_data['batch_dict'] = batch_dict
    original_data['cell_dict'] = cell_dict
    original_data['label_dict'] = label_dict
    original_data['pos_dict'] = pos_dict






    top_n_var = 250
    train_x_all = None
    cell_idx_all = None
    cell_type_all = None
    cell_pos_all = None
    batch_idx_all = None
    num_cells_all = 0


    for batch_num in batch_num_list:
        train_x = batch_dict[batch_num]
        # train_x = eval('batch_dict_{norm_type}[batch_num]'.format(norm_type=norm_type))
        # train_x = batch_dict[batch_num]
        cell_idx = cell_dict[batch_num]
        cell_type = label_dict[batch_num]
        cell_pos = pos_dict[batch_num]
        # batch_FE = FE_dict[batch_num]
        cell_related_ind = (cell_idx!=0)

        num_cells = int(np.max(cell_idx))
        # num_cells = 2
        train_x = train_x[cell_related_ind,:]

        cell_idx = cell_idx[cell_related_ind]
        cell_type = cell_type[cell_related_ind]
        # cell_type = np.ones(shape=cell_idx.shape)
        cell_pos = cell_pos[cell_related_ind]





        var_li = []
        normed_var_li = []
        for i in range(train_x.shape[1]):
            cur_col = train_x[:,i]
        #     cur_col= cur_row/np.sum(cur_col)
        #     cur_entropy = entropy(cur_col)
            cur_var = np.var(cur_col)
            cur_normed_var = cur_var/np.mean(cur_col)
        #     entropy_li.append(cur_entropy)
            var_li.append(cur_var)
            normed_var_li.append(cur_normed_var)
        # entropy_li = np.array(entropy_li)
        var_li = np.array(var_li)
        normed_var_li = np.array(normed_var_li)
        sort_ind = np.flip(np.argsort(normed_var_li),axis=0)
        sort_val = np.flip(np.sort(normed_var_li),axis=0)
        
        if train_x_all is None:
            train_x_all = train_x
        else:
            train_x_all = np.vstack([train_x_all,train_x])
        if cell_idx_all is None:
            cell_idx_all = cell_idx
        else:
            cell_idx_all = np.hstack([cell_idx_all,cell_idx+np.max(cell_idx_all)])
        if cell_type_all is None:
            cell_type_all = cell_type
        else:
            cell_type_all = np.hstack([cell_type_all,cell_type])
        if cell_pos_all is None:
            cell_pos_all = cell_pos
        else:
            cell_pos_all = np.hstack([cell_pos_all,cell_pos])
        if batch_idx_all is None:
            batch_idx_all = batch_num*np.ones(shape=(cell_idx.shape))
        else:
            batch_idx_all = np.hstack([batch_idx_all,batch_num*np.ones(shape=(cell_idx.shape))])


    train_x = train_x_all
    cell_idx = cell_idx_all
    cell_type = cell_type_all
    cell_pos = cell_pos_all
    batch_idx = batch_idx_all
    num_cells = np.max(cell_idx)
    if mode=='none':
        train_x = train_x
    elif mode=='median':
        train_x = train_x/np.percentile(train_x,50,axis=1,keepdims=True)
        train_x = np.log(train_x+1)
    elif mode=='total':
        train_x = train_x/np.sum(train_x,axis=1,keepdims=True)
        train_x = np.log(train_x+1)

    if norm=='standard':
        train_x = StandardScaler().fit_transform(train_x)
    elif norm=='l1':
        train_x = Normalizer(norm='l1').fit_transform(train_x)
    elif norm=='l2':
        train_x = Normalizer(norm='l2').fit_transform(train_x)
    elif norm=='none':
        train_x = train_x

    cell_related_data['train_x'] = train_x
    cell_related_data['cell_idx'] = cell_idx
    cell_related_data['cell_type'] = cell_type
    cell_related_data['cell_pos'] = cell_pos
    cell_related_data['batch_idx'] =batch_idx
    cell_related_data['num_cells'] = num_cells
    return original_data,cell_related_data

# %%
def get_labeling(label,cell_idx,cell_pos):
#     y是cell-rela的细胞对应的标签
#     print('pred_y',np.unique(label))
    labeling = np.zeros(shape=(65536,1))
    b = cell_idx.copy()
    num_cells = label.shape[0]
    for i in range(num_cells):
        b[b==i+1] = label[i] + 1
#     print(cell_pos)
#     print('b',np.unique(b))
#     cell_pos = cell_pos.astype('int')
    labeling[cell_pos.astype('int')-1,0] = b

    return labeling

# %%
def show_images(images, cols = 1, titles = None,cmps='jet'):
    """Display a list of images in a single figure with matplotlib.
    
    Parameters
    ---------
    images: List of np.arrays compatible with plt.imshow.
    
    cols (Default = 1): Number of columns in figure (number of rows is 
                        set to np.ceil(n_images/float(cols))).
    
    titles: List of titles corresponding to each image. Must have
            the same length as titles.
    """
    assert((titles is None)or (len(images) == len(titles)))
    n_images = len(images)
    if titles is None: titles = ['Image (%d)' % i for i in range(1,n_images + 1)]
    fig = plt.figure()
    for n, (image, title) in enumerate(zip(images, titles)):
#         print(cols)
#         cmp = cmps[n]
        a = fig.add_subplot(cols, np.ceil(n_images/float(cols)), n + 1)
#         if image.ndim == 2:
#             plt.gray()
        
    
        plt.imshow(image,cmap=cmps)
        plt.xticks([])
        plt.yticks([])
        a.set_title(title)
    fig.set_size_inches(np.array(fig.get_size_inches()) * n_images)
    plt.show()
    

import matplotlib.pyplot as plt
# uh_pred = hdbscan.HDBSCAN(min_cluster_size=30).fit_predict(rep_embed)
# pred_y = np.ones(shape=(np.max(cell_idx)))
# pred_y = KMeans(3).fit_predict(sim_mat_bak)
# pred_y = SIMLR(sim_mat_bak,-8)
# pred_y = SpectralClustering(4,affinity='precomputed').fit_predict(sim_mat_order_bak)
# pred_y = AgglomerativeClustering(4,affinity='precomputed',linkage='complete').fit_predict(1/(input_sim_mat+1))
def plot_label_image(pred_y,cmp,save=None,mask=None):
    
    to_labeling_pred_y = np.array(pred_y.astype('int'))
    # to_labeling_pred_y[coc[448,:]>0]=3
    # to_labeling_pred_y = resultsLWEA[:,2]
    # to_labeling_pred_y = label_list_FF[2]
    # to_labeling_pred_y = label_list[3]
    # to_labeling_pred_y[mark_list]=2
#     cluster_cmp = sns.hls_palette(np.unique(to_labeling_pred_y).shape[0])
    unique_cls = np.unique(pred_y).shape[0]
    cluster_cmp = cmp.copy()
    
    if mask is not None:
        for to_mask in range(unique_cls):
            if to_mask in mask:
                continue
                
            cluster_cmp[to_mask]='k'
    labeling_plot_cmp = ['k']
    labeling_plot_cmp.extend(cluster_cmp)
    labeling = get_labeling(to_labeling_pred_y-np.min(to_labeling_pred_y),cell_idx,cell_pos)
    # labeling[labeling==5]=0
    img1 = labeling.reshape((256,256))
    plt.figure(figsize=(5,5))
    # plt.imshow(img1)
    ticks=np.arange(np.min(img1)+1,np.max(img1)+1)
    boundaries = np.arange(np.min(img1)+0.5,np.max(img1)+1.5)
#     with sns.plotting_context(font_scale=font_scale):
    sns.heatmap(img1,cmap=labeling_plot_cmp,linewidths=0,linecolor='k',square=True,cbar_kws={"ticks":ticks, "boundaries":boundaries,'fraction':0.046,'pad':0.04})
    # sns.heatmap(img1,cmap=labeling_plot_cmp,square=True,ad':0.04})
#     plt.legend(fontsize=font_size)
    plt.xticks([])
    plt.yticks([])
    if save is not None:
        plt.savefig(save,transparent=False,format='pdf',bbox_inches='tight')

#     for i in range(num_cells):
#         cur_idx = i + 1
#         cur_ind = cell_pos[cell_idx==cur_idx][0]
#     #     print(ind2ij(cur_ind,256,0))
#     #     print(ind2ij(cur_ind,256,1))

#         plt.annotate(str(cur_idx-1),(ind2ij(cur_ind,256,1),ind2ij(cur_ind,256,0)),color='red')

   
    plt.show()
    
    
    
    
def plot_label_image(pred_y,cmp,save=None,mask=None,figsize=(5,5),anno=False,ifshow=True):
    
    to_labeling_pred_y = np.array(pred_y.astype('int'))
    to_labeling_pred_y_min = to_labeling_pred_y.min()
    # to_labeling_pred_y[coc[448,:]>0]=3
    # to_labeling_pred_y = resultsLWEA[:,2]
    # to_labeling_pred_y = label_list_FF[2]
    # to_labeling_pred_y = label_list[3]
    # to_labeling_pred_y[mark_list]=2
#     cluster_cmp = sns.hls_palette(np.unique(to_labeling_pred_y).shape[0])
    unique_cls = np.unique(pred_y).shape[0]
#     unique_cls_mask = [unique_cls[m] for m in mask]
    cluster_cmp = cmp.copy()
    
    if mask is not None:
        for to_mask in range(unique_cls):
            if to_mask in mask:
                continue
#             print(type(cluster_cmp))
#             print(to_mask,cluster_cmp)
            cluster_cmp[to_mask]='k'
    labeling_plot_cmp = ['k']
    labeling_plot_cmp.extend(cluster_cmp)
    labeling = get_labeling(to_labeling_pred_y-np.min(to_labeling_pred_y),cell_idx,cell_pos)
    # labeling[labeling==5]=0
    img1 = labeling.reshape((256,256))
    plt.figure(figsize=figsize)
    # plt.imshow(img1)
    ticks=np.arange(np.min(img1)+1,np.max(img1)+1)
    boundaries = np.arange(np.min(img1)+0.5,np.max(img1)+1.5)
#     with sns.plotting_context(font_scale=font_scale):
    sns.heatmap(img1,cmap=labeling_plot_cmp,linewidths=0,linecolor='k',square=True,cbar_kws={"ticks":ticks, "boundaries":boundaries,'fraction':0.046,'pad':0.04})
    # sns.heatmap(img1,cmap=labeling_plot_cmp,square=True,ad':0.04})
#     plt.legend(fontsize=font_size)
    plt.xticks([])
    plt.yticks([])
    if save is not None:
        plt.savefig(save,transparent=False,format='png',bbox_inches='tight')

    if anno:
        num_cells = pred_y.shape[0]
        for i in range(num_cells):
            cur_idx = i + 1
            cur_ind = cell_pos[cell_idx==cur_idx][0]
        #     print(ind2ij(cur_ind,256,0))
        #     print(ind2ij(cur_ind,256,1))
            if to_labeling_pred_y[i]-to_labeling_pred_y_min in mask:
                plt.annotate(str(cur_idx-1),(ind2ij(cur_ind,256,1),ind2ij(cur_ind,256,0)),color='red')

    if ifshow:
        plt.show()

# %% [markdown]
# # experiment

# %% [markdown]
# ## de novo SEAM

# %% [markdown]
# ### load SIMS data

# %%
1+1
# Out:
# 2

# %%
data_mat_filename_temp = '/home/yzy/bioSIMS/data/process/{0}/cut/rst/datamat.mat'
matter_list_filename_temp='/home/yzy/bioSIMS/data/process/{0}/preprocess/matters_candidate.pkl'




data = 'mix_cancer_idu_normal_gaussian_ada'
test_sample_temp='/home/yzy/bioSIMS/data/process/{0}/preprocess/test_samples_168.mat'



matter_list_filename = matter_list_filename_temp.format(data)
data_mat_filename = data_mat_filename_temp.format(data)
test_sample_filename = test_sample_temp.format(data)
test_sample_all = sio.loadmat(test_sample_filename)['test_samples']
mode='none'
norm='none'
[original_data,cell_related_data]=get_train_data(data_mat_filename,mode,norm,batch_num_list=[1])
train_x=cell_related_data['train_x']
cell_idx=cell_related_data['cell_idx']
cell_pos=cell_related_data['cell_pos']
num_cells = np.max(cell_idx)
matter_list = pickle.load(open(matter_list_filename,'rb'))
matter_list = np.array(matter_list)

# %% [markdown]
# ### normalize SIMS data

# %%
train_x_tmp = train_x.copy()

# %%
train_x_median = (train_x_tmp+1)/(np.percentile(train_x_tmp,50,axis=1,keepdims=True)+1)
train_x_total = train_x/np.sum(train_x,axis=1,keepdims=True)
train_x_median = np.log(train_x_median+1)
train_x_total = np.log(train_x_total+1)
# train_x_A = (train_x+1)/(train_x[:,matter_list==134.06]+1)
sum_profile_list_median = []
sum_profile_list_total = []

max_profile_list_median = []
max_profile_list = []
mean_profile_list_median = []
max_profile_list_total = []
mean_profile_list_total = []
mean_profile_list=[]
# mean_profile_list_A=[]
# max_profile_list_A = []
for i in range(num_cells):
        mean_profile_list_median.append(np.mean(train_x_median[cell_idx==i+1,:],axis=0))
        max_profile_list_median.append(np.max(train_x_median[cell_idx==i+1,:],axis=0))
        max_profile_list.append(np.max(train_x[cell_idx==i+1,:],axis=0))
#         mean_profile_list_A.append(np.mean(train_x_A[cell_idx==i+1,:],axis=0))
#         max_profile_list_A.append(np.max(train_x_A[cell_idx==i+1,:],axis=0))
        
        sum_profile_list_median.append(np.sum(train_x_median[cell_idx==i+1,:],axis=0))
        mean_profile_list.append(np.mean(train_x[cell_idx==i+1,:],axis=0))
        mean_profile_list_total.append(np.mean(train_x_total[cell_idx==i+1,:],axis=0))
        max_profile_list_total.append(np.max(train_x_total[cell_idx==i+1,:],axis=0))
        sum_profile_list_total.append(np.sum(train_x_total[cell_idx==i+1,:],axis=0))
        
mean_profile_list_median = np.array(mean_profile_list_median)
max_profile_list_median = np.array(max_profile_list_median)
mean_profile_list_total = np.array(mean_profile_list_total)
max_profile_list_total = np.array(max_profile_list_total)
sum_profile_list_median = np.array(sum_profile_list_median)
sum_profile_list_total = np.array(sum_profile_list_total)
mean_profile_list = np.array(mean_profile_list)
max_profile_list = np.array(max_profile_list)
# mean_profile_list_A = np.array(mean_profile_list_A)
# max_profile_list_A = np.array(max_profile_list_A)

# %% [markdown]
# ### run SIMS-ID

# %%
SIMS_id_t_list = [5,10,15,20,25,30,35,40,50]



HEG_list = matter_list
# HEG_list = key_matters
# HEG_list = get_adj_matters(key_matters,matter_list)


HEG_col_idx = [list(matter_list).index(HEG) for HEG in HEG_list]

netwidths=[128,128,128]
# netwidths=[20,20,20]


error_threshold=0
train_x_HEG = train_x_tmp[:,HEG_col_idx]
train_x_preprocess = train_x_HEG
# train_x_preprocess = (train_x_HEG+1)/(train_x_HEG[:,matter_list==133.92]+1)

train_x_preprocess = (train_x_HEG)/np.sum(train_x_HEG,axis=1,keepdims=True)
# train_x_preprocess = (train_x_HEG+1)/(np.percentile(train_x_HEG,50,axis=1,keepdims=True)+1)



rep_list = get_distil_rep(train_x_preprocess,cell_idx,num_cells,SIMS_id_t_list, verbose=False,epochs=500,netwidths=netwidths,low_dim=netwidths[2],error_threshold=error_threshold)
# Out:
# /home/yzy/anaconda3/envs/scaden/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/500
# 1821/1821 [==============================] - 1s 316us/step - loss: 5.2235 - softmax_loss: 5.2234 - center_loss: 0.2100
# Epoch 2/500
# 1821/1821 [==============================] - 0s 96us/step - loss: 5.1129 - softmax_loss: 5.1124 - center_loss: 4.4314
# Epoch 3/500
# 1821/1821 [==============================] - 0s 96us/step - loss: 5.0555 - softmax_loss: 5.0578 - center_loss: 6.0850
# Epoch 4/500
# 1821/1821 [==============================] - 0s 95us/step - loss: 5.0463 - softmax_loss: 5.0422 - center_loss: 5.6695
# Epoch 5/500
# 1821/1821 [==============================] - 0s 86us/step - loss: 5.0409 - softmax_loss: 5.0432 - center_loss: 6.1112
# Epoch 6/500
# 1821/1821 [==============================] - 0s 70us/step - loss: 5.0357 - softmax_loss: 5.0397 - center_loss: 5.3233
# Epoch 7/500
# 1821/1821 [==============================] - 0s 70us/step - loss: 5.0272 - softmax_loss: 5.0300 - center_loss: 5.2237
# Epoch 8/500
# 1821/1821 [==============================] - 0s 105us/step - loss: 5.0159 - softmax_loss: 5.0209 - center_loss: 4.8789
# Epoch 9/500
# 1821/1821 [==============================] - 0s 75us/step - loss: 4.9929 - softmax_loss: 4.9897 - center_loss: 4.6620
# Epoch 10/500
# 1821/1821 [==============================] - 0s 74us/step - loss: 4.9502 - softmax_loss: 4.9501 - center_loss: 4.5196
# Epoch 11/500
# 1821/1821 [==============================] - 0s 79us/step - loss: 4.8690 - softmax_loss: 4.8697 - center_loss: 4.6864
# Epoch 12/500
# 1821/1821 [==============================] - 0s 78us/step - loss: 4.7283 - softmax_loss: 4.7336 - center_loss: 5.7130
# Epoch 13/500
# 1821/1821 [==============================] - 0s 74us/step - loss: 4.5667 - softmax_loss: 4.5669 - center_loss: 8.0074
# Epoch 14/500
# 1821/1821 [==============================] - 0s 80us/step - loss: 4.4516 - softmax_loss: 4.4494 - center_loss: 10.9368
# Epoch 15/500
# 1821/1821 [==============================] - 0s 73us/step - loss: 4.3853 - softmax_loss: 4.3885 - center_loss: 14.9754
# Epoch 16/500
# 1821/1821 [==============================] - 0s 77us/step - loss: 4.3317 - softmax_loss: 4.3359 - center_loss: 19.6622
# Epoch 17/500
# 1821/1821 [==============================] - 0s 92us/step - loss: 4.2866 - softmax_loss: 4.2877 - center_loss: 24.9561
# Epoch 18/500
# 1821/1821 [==============================] - 0s 85us/step - loss: 4.2414 - softmax_loss: 4.2380 - center_loss: 32.7003
# Epoch 19/500
# 1821/1821 [==============================] - 0s 95us/step - loss: 4.2155 - softmax_loss: 4.2195 - center_loss: 40.9367
# Epoch 20/500
500
# 1821/1821 [==============================] - 0s 59us/step - loss: 3.3156 - softmax_loss: 3.3164 - center_loss: 237.6958
# Epoch 74/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 3.3215 - softmax_loss: 3.3171 - center_loss: 241.4756
# Epoch 75/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 3.3181 - softmax_loss: 3.3145 - center_loss: 241.7422
# Epoch 76/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 3.3008 - softmax_loss: 3.3024 - center_loss: 242.8403
# Epoch 77/500
# 1821/1821 [==============================] - 0s 73us/step - loss: 3.2981 - softmax_loss: 3.3046 - center_loss: 242.0223
# Epoch 78/500
# 1821/1821 [==============================] - 0s 64us/step - loss: 3.3010 - softmax_loss: 3.2978 - center_loss: 244.3499
# Epoch 79/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 3.3009 - softmax_loss: 3.3091 - center_loss: 244.2395
# Epoch 80/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 3.2955 - softmax_loss: 3.2933 - center_loss: 245.2624
# Epoch 81/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 3.2866 - softmax_loss: 3.2875 - center_loss: 245.8908
# Epoch 82/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 3.2854 - softmax_loss: 3.2884 - center_loss: 247.2812
# Epoch 83/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 3.2928 - softmax_loss: 3.2983 - center_loss: 249.1007
# Epoch 84/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 3.2662 - softmax_loss: 3.2663 - center_loss: 248.3224
# Epoch 85/500
# 1821/1821 [==============================] - 0s 60us/step - loss: 3.2717 - softmax_loss: 3.2723 - center_loss: 248.2644
# Epoch 86/500
# 1821/1821 [==============================] - 0s 63us/step - loss: 3.2829 - softmax_loss: 3.2903 - center_loss: 251.0160
# Epoch 87/500
# 1821/1821 [==============================] - 0s 60us/step - loss: 3.2713 - softmax_loss: 3.2714 - center_loss: 249.5523
# Epoch 88/500
# 1821/1821 [==============================] - 0s 60us/step - loss: 3.2700 - softmax_loss: 3.2709 - center_loss: 254.5092
# Epoch 89/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 3.2837 - softmax_loss: 3.2876 - center_loss: 252.1120
# Epoch 90/500
# 1821/1821 [==============================] - 0s 60us/step - loss: 3.2713 - softmax_loss: 3.2655 - center_loss: 251.6860
# Epoch 91/500
# 1821/1821 [==============================] - 0s 60us/step - loss: 3.2604 - softmax_loss: 3.2672 - center_loss: 252.8341
# Epoch 92/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 3.2648 - softmax_loss: 3.2742 - center_loss: 255.7098
# Epoch 93/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 3.2591 - softmax_loss: 3.2591 - center_loss: 253.7745
# Epoch 94/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 3.2544 - softmax_loss: 3.2452 - center_loss: 256.3871
# Epoch 95/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 3.2507 - softmax_loss: 3.2562 - center_loss: 254.5300
# Epoch 96/500
# 1821/1821 [==============================] - 0s 66us/step - loss: 3.2575 - softmax_loss: 3.2488 - center_loss: 257.6225
# Epoch 97/500
# 1821/1821 [==============================] - 0s 60us/step - loss: 3.2477 - softmax_loss: 3.2437 - center_loss: 257.9614
# Epoch 98/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 3.2510 - softmax_loss: 3.2530 - center_loss: 258.1818
# Epoch 99/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 3.2622 - softmax_loss: 3.2585 - center_loss: 259.6962
# Epoch 100/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 3.2506 - softmax_loss: 3.2553 - center_loss: 259.2083
# Epoch 101/500
# 1821/1821 [==============================] - 0s 60us/step - loss: 3.2504 - softmax_loss: 3.2521 - center_loss: 258.7310
# Epoch 102/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 3.2544 - softmax_loss: 3.2515 - center_loss: 260.3402
# Epoch 103/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 3.2425 - softmax_loss: 3.2453 - center_loss: 258.4150
# Epoch 104/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 3.2496 - softmax_loss: 3.2498 - center_loss: 259.8374
# Epoch 105/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 3.2377 - softmax_loss: 3.2408 - center_loss: 261.4079
# Epoch 106/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 3.2350 - softmax_loss: 3.2324 - center_loss: 260.6543
# Epoch 107/500
# 1821/1821 [==============================] - 0s 71us/step - loss: 3.2432 - softmax_loss: 3.2433 - center_loss: 260.9951
# Epoch 108/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 3.2348 - softmax_loss: 3.2393 - center_loss: 261.0718
# Epoch 109/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 3.2266 - softmax_loss: 3.2379 - center_loss: 259.8402
# Epoch 110/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 3.2357 - softmax_loss: 3.2304 - center_loss: 260.8350
# Epoch 111/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 3.2318 - softmax_loss: 3.2356 - center_loss: 260.9173
# Epoch 112/500
# 1821/1821 [==============================] - 0s 64us/step - loss: 3.2284 - softmax_loss: 3.2319 - center_loss: 261.6972
# Epoch 113/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 3.2249 - softmax_loss: 3.2198 - center_loss: 263.5345
# Epoch 114/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 3.2223 - softmax_loss: 3.2175 - center_loss: 262.3257
# Epoch 115/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 3.2303 - softmax_loss: 3.2330 - center_loss: 262.2469
# Epoch 116/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 3.2185 - softmax_loss: 3.2159 - center_loss: 262.0852
# Epoch 117/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 3.2180 - softmax_loss: 3.2148 - center_loss: 264.3039
# Epoch 118/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 3.2156 - softmax_loss: 3.2164 - center_loss: 264.8355
# Epoch 119/500
# 1821/1821 [==============================] - 0s 63us/step - loss: 3.2293 - softmax_loss: 3.2306 - center_loss: 264.7137
# Epoch 120/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 3.2256 - softmax_loss: 3.2254 - center_loss: 264.1996
# Epoch 121/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 3.2103 - softmax_loss: 3.2018 - center_loss: 266.7608
# Epoch 122/500
# 1821/1821 [==============================] - 0s 63us/step - loss: 3.2159 - softmax_loss: 3.2179 - center_loss: 262.2172
# Epoch 123/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 3.2218 - softmax_loss: 3.2242 - center_loss: 264.8241
# Epoch 124/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 3.2221 - softmax_loss: 3.2227 - center_loss: 263.8011
# Epoch 125/500
# 1821/1821 [==============================] - 0s 89us/step - loss: 3.2094 - softmax_loss: 3.2068 - center_loss: 266.4077
# Epoch 126/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 3.2099 - softmax_loss: 3.2069 - center_loss: 263.7576
# Epoch 127/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 3.2071 - softmax_loss: 3.2085 - center_loss: 265.8607
# Epoch 128/500
# 1821/1821 [==============================] - 0s 63us/step - loss: 3.2357 - softmax_loss: 3.2373 - center_loss: 266.5698
# Epoch 129/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 3.2019 - softmax_loss: 3.2080 - center_loss: 264.8039
# Epoch 130/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 3.1991 - softmax_loss: 3.2028 - center_loss: 263.8676
# Epoch 131/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 3.2047 - softmax_loss: 3.2095 - center_loss: 265.6095
# Epoch 132/500
# 1821/1821 [==============================] - 0s 78us/step - loss: 3.2102 - softmax_loss: 3.2101 - center_loss: 262.9816
# Epoch 133/500
# 1821/1821 [==============================] - 0s 82us/step - loss: 3.2046 - softmax_loss: 3.2092 - center_loss: 263.6280
# Epoch 134/500
# 1821/1821 [==============================] - 0s 78us/step - loss: 3.2006 - softmax_loss: 3.2045 - center_loss: 262.9120
# Epoch 135/500
# 1821/1821 [==============================] - 0s 71us/step - loss: 3.1980 - softmax_loss: 3.2035 - center_loss: 265.8928
# Epoch 136/500
# 1821/1821 [==============================] - 0s 71us/step - loss: 3.1928 - softmax_loss: 3.1949 - center_loss: 265.5790
# Epoch 137/500
# 1821/1821 [==============================] - 0s 76us/step - loss: 3.2042 - softmax_loss: 3.2102 - center_loss: 265.6118
# Epoch 138/500
# 1821/1821 [==============================] - 0s 70us/step - loss: 3.1923 - softmax_loss: 3.2004 - center_loss: 264.6906
# Epoch 139/500
# 1821/1821 [==============================] - 0s 69us/step - loss: 3.1918 - softmax_loss: 3.1943 - center_loss: 265.2046
# Epoch 140/500
# 1821/1821 [==============================] - 0s 73us/step - loss: 3.1913 - softmax_loss: 3.1959 - center_loss: 265.3242
# Epoch 141/500
# 1821/1821 [==============================] - 0s 75us/step - loss: 3.1925 - softmax_loss: 3.1911 - center_loss: 265.0772
# Epoch 142/500
# 1821/1821 [==============================] - 0s 71us/step - loss:
500
# 1821/1821 [==============================] - 0s 69us/step - loss: 2.8669 - softmax_loss: 2.8692 - center_loss: 270.3710
# Epoch 224/500
# 1821/1821 [==============================] - 0s 74us/step - loss: 2.8591 - softmax_loss: 2.8688 - center_loss: 271.5765
# Epoch 225/500
# 1821/1821 [==============================] - 0s 75us/step - loss: 2.8551 - softmax_loss: 2.8576 - center_loss: 270.3803
# Epoch 226/500
# 1821/1821 [==============================] - 0s 65us/step - loss: 2.8483 - softmax_loss: 2.8447 - center_loss: 271.9636
# Epoch 227/500
# 1821/1821 [==============================] - 0s 71us/step - loss: 2.8413 - softmax_loss: 2.8395 - center_loss: 270.6079
# Epoch 228/500
# 1821/1821 [==============================] - 0s 71us/step - loss: 2.8483 - softmax_loss: 2.8500 - center_loss: 271.8549
# Epoch 229/500
# 1821/1821 [==============================] - 0s 77us/step - loss: 2.8320 - softmax_loss: 2.8302 - center_loss: 273.0866
# Epoch 230/500
# 1821/1821 [==============================] - 0s 70us/step - loss: 2.8264 - softmax_loss: 2.8384 - center_loss: 271.9400
# Epoch 231/500
# 1821/1821 [==============================] - 0s 74us/step - loss: 2.8263 - softmax_loss: 2.8257 - center_loss: 274.0706
# Epoch 232/500
# 1821/1821 [==============================] - 0s 84us/step - loss: 2.8419 - softmax_loss: 2.8419 - center_loss: 273.9344
# Epoch 233/500
# 1821/1821 [==============================] - 0s 85us/step - loss: 2.8122 - softmax_loss: 2.8129 - center_loss: 273.3116
# Epoch 234/500
# 1821/1821 [==============================] - 0s 65us/step - loss: 2.8174 - softmax_loss: 2.8282 - center_loss: 273.8442
# Epoch 235/500
# 1821/1821 [==============================] - 0s 71us/step - loss: 2.8095 - softmax_loss: 2.8106 - center_loss: 274.3817
# Epoch 236/500
# 1821/1821 [==============================] - 0s 75us/step - loss: 2.8066 - softmax_loss: 2.7998 - center_loss: 276.3281
# Epoch 237/500
# 1821/1821 [==============================] - 0s 70us/step - loss: 2.8094 - softmax_loss: 2.8114 - center_loss: 275.7719
# Epoch 238/500
# 1821/1821 [==============================] - 0s 74us/step - loss: 2.8007 - softmax_loss: 2.7977 - center_loss: 274.5085
# Epoch 239/500
# 1821/1821 [==============================] - 0s 73us/step - loss: 2.8049 - softmax_loss: 2.8093 - center_loss: 275.5342
# Epoch 240/500
# 1821/1821 [==============================] - 0s 74us/step - loss: 2.7921 - softmax_loss: 2.7893 - center_loss: 275.3748
# Epoch 241/500
# 1821/1821 [==============================] - 0s 81us/step - loss: 2.7902 - softmax_loss: 2.7868 - center_loss: 274.5357
# Epoch 242/500
# 1821/1821 [==============================] - 0s 67us/step - loss: 2.7957 - softmax_loss: 2.8028 - center_loss: 275.3443
# Epoch 243/500
# 1821/1821 [==============================] - 0s 69us/step - loss: 2.7864 - softmax_loss: 2.7884 - center_loss: 275.7260
# Epoch 244/500
# 1821/1821 [==============================] - 0s 72us/step - loss: 2.8037 - softmax_loss: 2.8116 - center_loss: 275.4502
# Epoch 245/500
# 1821/1821 [==============================] - 0s 71us/step - loss: 2.7712 - softmax_loss: 2.7755 - center_loss: 275.1082
# Epoch 246/500
# 1821/1821 [==============================] - 0s 73us/step - loss: 2.7764 - softmax_loss: 2.7821 - center_loss: 275.0305
# Epoch 247/500
# 1821/1821 [==============================] - 0s 70us/step - loss: 2.7606 - softmax_loss: 2.7598 - center_loss: 276.6662
# Epoch 248/500
# 1821/1821 [==============================] - 0s 70us/step - loss: 2.7599 - softmax_loss: 2.7626 - center_loss: 275.7480
# Epoch 249/500
# 1821/1821 [==============================] - 0s 76us/step - loss: 2.7697 - softmax_loss: 2.7755 - center_loss: 277.2361
# Epoch 250/500
# 1821/1821 [==============================] - 0s 74us/step - loss: 2.7531 - softmax_loss: 2.7590 - center_loss: 276.1618
# Epoch 251/500
# 1821/1821 [==============================] - 0s 77us/step - loss: 2.7652 - softmax_loss: 2.7695 - center_loss: 278.6548
# Epoch 252/500
# 1821/1821 [==============================] - 0s 75us/step - loss: 2.7531 - softmax_loss: 2.7537 - center_loss: 275.7171 0s - loss: 2.6589 - softmax_loss: 2.6589 - center_loss: 286.
# Epoch 253/500
# 1821/1821 [==============================] - 0s 70us/step - loss:
500
# 1821/1821 [==============================] - 0s 61us/step - loss: 2.4860 - softmax_loss: 2.4872 - center_loss: 305.6958
# Epoch 333/500
# 1821/1821 [==============================] - 0s 58us/step - loss: 2.4747 - softmax_loss: 2.4749 - center_loss: 305.3323
# Epoch 334/500
# 1821/1821 [==============================] - 0s 72us/step - loss: 2.4881 - softmax_loss: 2.4956 - center_loss: 305.4684
# Epoch 335/500
# 1821/1821 [==============================] - 0s 75us/step - loss: 2.4685 - softmax_loss: 2.4697 - center_loss: 304.8472
# Epoch 336/500
# 1821/1821 [==============================] - 0s 82us/step - loss: 2.4728 - softmax_loss: 2.4772 - center_loss: 307.6678
# Epoch 337/500
# 1821/1821 [==============================] - 0s 66us/step - loss: 2.4608 - softmax_loss: 2.4647 - center_loss: 305.7481
# Epoch 338/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 2.4501 - softmax_loss: 2.4483 - center_loss: 305.9778
# Epoch 339/500
# 1821/1821 [==============================] - 0s 57us/step - loss: 2.4677 - softmax_loss: 2.4702 - center_loss: 307.6559
# Epoch 340/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.4579 - softmax_loss: 2.4601 - center_loss: 308.1516
# Epoch 341/500
# 1821/1821 [==============================] - 0s 63us/step - loss: 2.4514 - softmax_loss: 2.4472 - center_loss: 307.2966
# Epoch 342/500
# 1821/1821 [==============================] - 0s 54us/step - loss: 2.4463 - softmax_loss: 2.4437 - center_loss: 305.2453
# Epoch 343/500
# 1821/1821 [==============================] - 0s 55us/step - loss: 2.4339 - softmax_loss: 2.4301 - center_loss: 308.9641
# Epoch 344/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.4312 - softmax_loss: 2.4370 - center_loss: 308.3296
# Epoch 345/500
# 1821/1821 [==============================] - 0s 57us/step - loss: 2.4402 - softmax_loss: 2.4471 - center_loss: 308.4193
# Epoch 346/500
# 1821/1821 [==============================] - 0s 56us/step - loss: 2.4448 - softmax_loss: 2.4483 - center_loss: 309.5616
# Epoch 347/500
# 1821/1821 [==============================] - 0s 57us/step - loss: 2.4369 - softmax_loss: 2.4340 - center_loss: 307.7021
# Epoch 348/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 2.4108 - softmax_loss: 2.4143 - center_loss: 311.1236
# Epoch 349/500
# 1821/1821 [==============================] - 0s 57us/step - loss: 2.4246 - softmax_loss: 2.4200 - center_loss: 310.1718
# Epoch 350/500
# 1821/1821 [==============================] - 0s 60us/step - loss: 2.4237 - softmax_loss: 2.4248 - center_loss: 308.2717
# Epoch 351/500
# 1821/1821 [==============================] - 0s 60us/step - loss: 2.4226 - softmax_loss: 2.4258 - center_loss: 311.5847
# Epoch 352/500
# 1821/1821 [==============================] - 0s 58us/step - loss: 2.4439 - softmax_loss: 2.4433 - center_loss: 312.2291
# Epoch 353/500
# 1821/1821 [==============================] - 0s 60us/step - loss: 2.4126 - softmax_loss: 2.4082 - center_loss: 309.8070
# Epoch 354/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 2.4427 - softmax_loss: 2.4420 - center_loss: 312.3499
# Epoch 355/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.4010 - softmax_loss: 2.4028 - center_loss: 309.4105
# Epoch 356/500
# 1821/1821 [==============================] - 0s 57us/step - loss: 2.3959 - softmax_loss: 2.3986 - center_loss: 311.4327
# Epoch 357/500
# ...
# Epoch 382/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.3111 - softmax_loss: 2.3142 - center_loss: 319.0258
# Epoch 383/500
# 1821/1821 [==============================] - 0s 60us/step - loss: 2.2964 - softmax_loss: 2.3048 - center_loss: 316.8979
# Epoch 384/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 2.3023 - softmax_loss: 2.3031 - center_loss: 318.2311
# Epoch 385/500
# 1821/1821 [==============================] - 0s 58us/step - loss: 2.2928 - softmax_loss: 2.2896 - center_loss: 319.8380
# Epoch 386/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 2.2968 - softmax_loss: 2.2971 - center_loss: 320.4260
# Epoch 387/500
# 1821/1821 [==============================] - 0s 58us/step - loss: 2.2916 - softmax_loss: 2.2887 - center_loss: 318.1371
# Epoch 388/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.2947 - softmax_loss: 2.2944 - center_loss: 321.2791
# Epoch 389/500
# 1821/1821 [==============================] - 0s 60us/step - loss: 2.2944 - softmax_loss: 2.3018 - center_loss: 319.9766
# Epoch 390/500
# 1821/1821 [==============================] - 0s 65us/step - loss: 2.2753 - softmax_loss: 2.2738 - center_loss: 320.3019
# Epoch 391/500
# 1821/1821 [==============================] - 0s 55us/step - loss: 2.2847 - softmax_loss: 2.2897 - center_loss: 319.6689
# Epoch 392/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.2634 - softmax_loss: 2.2619 - center_loss: 320.8951
# Epoch 393/500
# 1821/1821 [==============================] - 0s 58us/step - loss: 2.2628 - softmax_loss: 2.2645 - center_loss: 320.8669
# Epoch 394/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 2.2567 - softmax_loss: 2.2598 - center_loss: 321.7348
# Epoch 395/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.2596 - softmax_loss: 2.2599 - center_loss: 322.7411
# Epoch 396/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.2493 - softmax_loss: 2.2440 - center_loss: 322.0985
# Epoch 397/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.2451 - softmax_loss: 2.2521 - center_loss: 323.1736
# Epoch 398/500
# 1821/1821 [==============================] - 0s 56us/step - loss: 2.2301 - softmax_loss: 2.2274 - center_loss: 322.2499
# Epoch 399/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.2351 - softmax_loss: 2.2408 - center_loss: 323.2285
# Epoch 400/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.2237 - softmax_loss: 2.2182 - center_loss: 322.6795
# Epoch 401/500
# 1821/1821 [==============================] - 0s 58us/step - loss: 2.2315 - softmax_loss: 2.2283 - center_loss: 323.1242
# Epoch 402/500
# 1821/1821 [==============================] - 0s 57us/step - loss: 2.2310 - softmax_loss: 2.2316 - center_loss: 325.6095
# Epoch 403/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.2310 - softmax_loss: 2.2258 - center_loss: 323.3795
# Epoch 404/500
# 1821/1821 [==============================] - 0s 58us/step - loss: 2.2150 - softmax_loss: 2.2232 - center_loss: 326.4625
# Epoch 405/500
# 1821/1821 [==============================] - 0s 57us/step - loss: 2.2032 - softmax_loss: 2.2073 - center_loss: 324.5352
# Epoch 406/500
# 1821/1821 [==============================] - 0s 58us/step - loss: 2.1911 - softmax_loss: 2.2024 - center_loss: 325.6520
# Epoch 407/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 2.2037 - softmax_loss: 2.1995 - center_loss: 324.2441
# Epoch 408/500
# 1821/1821 [==============================] - 0s 57us/step - loss: 2.1995 - softmax_loss: 2.2038 - center_loss: 329.3715
# Epoch 409/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.1862 - softmax_loss: 2.1845 - center_loss: 325.7395
# Epoch 410/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.1926 - softmax_loss: 2.1977 - center_loss: 329.2554
# Epoch 411/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 2.1992 - softmax_loss: 2.1972 - center_loss: 326.7526
# Epoch 412/500
# 1821/1821 [==============================] - 0s 58us/step - loss: 2.1905 - softmax_loss: 2.1870 - center_loss: 328.9350
# Epoch 413/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 2.1739 - softmax_loss: 2.1685 - center_loss: 327.0761
# Epoch 414/500
# 1821/1821 [==============================] - 0s 58us/step - loss: 2.1750 - softmax_loss: 2.1702 - center_loss: 328.2014
# Epoch 415/500
# 1821/1821 [==============================] - 0s 62us/step - loss: 2.1907 - softmax_loss: 2.1866 - center_loss: 327.4120
# Epoch 416/500
# 1821/1821 [==============================] - 0s 58us/step - loss: 2.1648 - softmax_loss: 2.1652 - center_loss: 329.5956
# Epoch 417/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.1794 - softmax_loss: 2.1803 - center_loss: 329.8235
# Epoch 418/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.1679 - softmax_loss: 2.1656 - center_loss: 329.3786
# Epoch 419/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.1541 - softmax_loss: 2.1590 - center_loss: 330.1212
# Epoch 420/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.1593 - softmax_loss: 2.1515 - center_loss: 329.4526
# Epoch 421/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.1787 - softmax_loss: 2.1694 - center_loss: 330.8718
# Epoch 422/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.1579 - softmax_loss: 2.1690 - center_loss: 332.2661
# Epoch 423/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.1495 - softmax_loss: 2.1530 - center_loss: 332.8382
# Epoch 424/500
# 1821/1821 [==============================] - 0s 60us/step - loss: 2.1452 - softmax_loss: 2.1473 - center_loss: 331.9841
# Epoch 425/500
# 1821/1821 [==============================] - 0s 57us/step - loss: 2.1439 - softmax_loss: 2.1478 - center_loss: 333.1304
# Epoch 426/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 2.1358 - softmax_loss: 2.1386 - center_loss: 332.2003
# Epoch 427/500
# 1821/1821 [==============================] - 0s 58us/step - loss: 2.1330 - softmax_loss: 2.1318 - center_loss: 334.2931
# Epoch 428/500
# 1821/1821 [==============================] - 0s 60us/step - loss: 2.1475 - softmax_loss: 2.1429 - center_loss: 336.0595
# Epoch 429/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.1332 - softmax_loss: 2.1277 - center_loss: 335.1955
# Epoch 430/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 2.1393 - softmax_loss: 2.1400 - center_loss: 336.0286
# Epoch 431/500
# 1821/1821 [==============================] - 0s 58us/step - loss: 2.1435 - softmax_loss: 2.1428 - center_loss: 337.0935
# Epoch 432/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 2.1181 - softmax_loss: 2.1265 - center_loss: 338.1412
# Epoch 433/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.1291 - softmax_loss: 2.1336 - center_loss: 339.5263
# Epoch 434/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 2.1175 - softmax_loss: 2.1209 - center_loss: 336.4857
# Epoch 435/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 2.1132 - softmax_loss: 2.1093 - center_loss: 339.2553
# Epoch 436/500
# 1821/1821 [==============================] - 0s 86us/step - loss: 2.1045 - softmax_loss: 2.1069 - center_loss: 339.4662
# Epoch 437/500
# 1821/1821 [==============================] - 0s 69us/step - loss: 2.1220 - softmax_loss: 2.1255 - center_loss: 338.3272
# Epoch 438/500
# 1821/1821 [==============================] - 0s 69us/step - loss: 2.1174 - softmax_loss: 2.1263 - center_loss: 340.6556
# Epoch 439/500
# 1821/1821 [==============================] - 0s 72us/step - loss: 2.1090 - softmax_loss: 2.1148 - center_loss: 341.0457
# Epoch 440/500
# 1821/1821 [==============================] - 0s 69us/step - loss: 2.0975 - softmax_loss: 2.0898 - center_loss: 337.5345
# Epoch 441/500
# 1821/1821 [==============================] - 0s 68us/step - loss: 2.1009 - softmax_loss: 2.1023 - center_loss: 342.3653
# Epoch 442/500
# 1821/1821 [==============================] - 0s 70us/step - loss: 2.0988 - softmax_loss: 2.1032 - center_loss: 342.7790
# Epoch 443/500
# 1821/1821 [==============================] - 0s 72us/step - loss: 2.0904 - softmax_loss: 2.0905 - center_loss: 341.4513
# Epoch 444/500
# 1821/1821 [==============================] - 0s 68us/step - loss: 2.0962 - softmax_loss: 2.1030 - center_loss: 346.6026
# Epoch 445/500
# 1821/1821 [==============================] - 0s 79us/step - loss: 2.1136 - softmax_loss: 2.1070 - center_loss: 345.2826
# Epoch 446/500
# 1821/1821 [==============================] - 0s 71us/step - loss: 2.0932 - softmax_loss: 2.0915 - center_loss: 342.6864
# Epoch 447/500
# 1821/1821 [==============================] - 0s 57us/step - loss: 2.0998 - softmax_loss: 2.0997 - center_loss: 345.6757
# Epoch 448/500
# 1821/1821 [==============================] - 0s 66us/step - loss: 2.0926 - softmax_loss: 2.0954 - center_loss: 346.4396
# Epoch 449/500
# 1821/1821 [==============================] - 0s 57us/step - loss: 2.0774 - softmax_loss: 2.0830 - center_loss: 344.9539
# Epoch 450/500
# 1821/1821 [==============================] - 0s 58us/step - loss: 2.0960 - softmax_loss: 2.0975 - center_loss: 346.2861
# Epoch 451/500
# 1821/1821 [==============================] - 0s 61us/step - loss: 2.0854 - softmax_loss: 2.0768 - center_loss: 346.5374
# Epoch 452/500
# 1821/1821 [==============================] - 0s 58us/step - loss: 2.0849 - softmax_loss: 2.0887 - center_loss: 348.1495
# Epoch 453/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.0671 - softmax_loss: 2.0670 - center_loss: 346.5048
# Epoch 454/500
# 1821/1821 [==============================] - 0s 60us/step - loss: 2.0800 - softmax_loss: 2.0901 - center_loss: 347.0585
# Epoch 455/500
# 1821/1821 [==============================] - 0s 58us/step - loss: 2.0627 - softmax_loss: 2.0609 - center_loss: 348.6674
# Epoch 456/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.0577 - softmax_loss: 2.0583 - center_loss: 348.9494
# Epoch 457/500
# 1821/1821 [==============================] - 0s 60us/step - loss: 2.0584 - softmax_loss: 2.0494 - center_loss: 351.8626
# Epoch 458/500
# 1821/1821 [==============================] - 0s 60us/step - loss: 2.0740 - softmax_loss: 2.0713 - center_loss: 350.7437
# Epoch 459/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2
500
# 1821/1821 [==============================] - 0s 58us/step - loss: 2.0168 - softmax_loss: 2.0249 - center_loss: 369.4874
# Epoch 492/500
# 1821/1821 [==============================] - 0s 57us/step - loss: 2.0101 - softmax_loss: 2.0067 - center_loss: 367.7395
# Epoch 493/500
# 1821/1821 [==============================] - 0s 57us/step - loss: 2.0118 - softmax_loss: 2.0149 - center_loss: 370.8227
# Epoch 494/500
# 1821/1821 [==============================] - 0s 57us/step - loss: 2.0111 - softmax_loss: 2.0079 - center_loss: 369.2927
# Epoch 495/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 2.0048 - softmax_loss: 2.0125 - center_loss: 370.0844
# Epoch 496/500
# 1821/1821 [==============================] - 0s 60us/step - loss: 1.9818 - softmax_loss: 1.9900 - center_loss: 369.7625
# Epoch 497/500
# 1821/1821 [==============================] - 0s 57us/step - loss: 1.9978 - softmax_loss: 2.0040 - center_loss: 370.7773
# Epoch 498/500
# 1821/1821 [==============================] - 0s 58us/step - loss: 1.9784 - softmax_loss: 1.9879 - center_loss: 371.4983
# Epoch 499/500
# 1821/1821 [==============================] - 0s 59us/step - loss: 1.9998 - softmax_loss: 1.9930 - center_loss: 372.7958
# Epoch 500/500
# 1821/1821 [==============================] - 0s 58us/step - loss: 1.9935 - softmax_loss: 1.9899 - center_loss: 373.6822

# %% [markdown]
# ### run SIMLR

# %%
import SIMLR
input_rep = rep_list[0]

input_dist = squareform(pdist(input_rep,'cosine'))
rep_embed = umap.UMAP(metric='precomputed',n_neighbors=30,n_components=2).fit_transform(input_dist)

cluster_cmp = sns.hls_palette(np.unique(pred_y).shape[0])
labeling_plot_cmp = ['k']
labeling_plot_cmp.extend(cluster_cmp)

# %% [markdown]
# ### load anndata

# %%
tissue_name = 'mix_cancer'

a_cancer = ad.read_h5ad('/home/yzy/ipynbs/figures/Supp_bak_20200521/{0}/data.h5py'.format(tissue_name))

# %%
a_cancer.obsm['ID'] = a_cancer.uns['rep_list'][0]

# %% [markdown]
# ## Using ID representation

# %%
a = a_cancer.copy()
sc.pp.neighbors(a,use_rep='ID',metric='euclidean',n_neighbors=20)
sc.tl.leiden(a,resolution=0.1)
sc.tl.umap(a,)

sc.pl.umap(a,color=['leiden'],s=100,save=None)

# %%
cur_save = 'figures/Supp/{0}/cluster_map.png'.format(tissue_name)
cur_exp_name='leiden'
plot_label_image(a.obs[cur_exp_name],a.uns[cur_exp_name+'_colors'],mask=None,save=None)
# mouse0_kidney0_neg0_high0_20_None_auto

# %%
show_mz(1,test_sample_all,matter_list)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-133-74c4926d99ab> in <module>
# ----> 1 show_mz(1,test_sample_all,matter_list)
#
# <ipython-input-125-ccd09c038ec7> in show_mz(matter, test_sample, matter_list)
#       2     sns.set_style('white')
#       3     m_idx = np.where(matter_list==matter)
# ----> 4     show_img = np.reshape(test_sample[:,m_idx],(256,256))
#       5     plt.imshow(show_img,cmap='Reds')
#       6     plt.title(str(matter))
#
# ~/.local/lib/python3.7/site-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     290            [5, 6]])
#     291     """
# --> 292     return _wrapfunc(a, 'reshape', newshape, order=order)
#     293
#     294
#
# ~/.local/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      54 def _wrapfunc(obj, method, *args, **kwds):
#      55     try:
# ---> 56         return getattr(obj, method)(*args, **kwds)
#      57
#      58     # An AttributeError occurs if the object does not have
#
# ValueError: cannot reshape array of size 0 into shape (256,256)
